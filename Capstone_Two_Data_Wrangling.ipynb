# %% [markdown]
# # Capstone Two: Data Wrangling

# %% [markdown]
# ## Data Wrangling Step One: Data Collection

# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/j/Desktop/Capstone_Two'

# %%
os.chdir('/Users/j/Desktop/Capstone_Two')

# %%
os.getcwd()
# Out:
# '/Users/j/Desktop/Capstone_Two'

# %%
df = pd.read_csv('/Users/j/Desktop/Capstone_Two/adult.data',header=None)

# %% [markdown]
# ## Data Wrangling Step Two: Data Organization

# %% [markdown]
# This step is not necessary because only one data source is used.

# %% [markdown]
# ## Data Wrangling Step Three and Four: Data Definition and Data Cleaning

# %%
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.describe()
# Out:
#                  0             2             4             10            11  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  12
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32561 non-null  int64
#  1   1       32561 non-null  object
#  2   2       32561 non-null  int64
#  3   3       32561 non-null  object
#  4   4       32561 non-null  int64
#  5   5       32561 non-null  object
#  6   6       32561 non-null  object
#  7   7       32561 non-null  object
#  8   8       32561 non-null  object
#  9   9       32561 non-null  object
#  10  10      32561 non-null  int64
#  11  11      32561 non-null  int64
#  12  12      32561 non-null  int64
#  13  13      32561 non-null  object
#  14  14      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns = ['age','workclass','fnlwgt','education','educationnum','maritalstatus','occupation','relationship','race','sex','capitalgain','capitalloss','hoursperweek','nativecountry','income']

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income
# 0         2174            0            40   United-States   <=50K
# ...

# %%
df.age.sort_values(ascending=False).head()
# Out:
# 10210    90
# 8963     90
# 5104     90
# 32277    90
# 24043    90
# Name: age, dtype: int64

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income
# 0         2174            0            40   United-States   <=50K
# ...

# %%
df.hoursperweek.sort_values(ascending=False).head()
# Out:
# 1887     99
# 4308     99
# 10143    99
# 30610    99
# 25806    99
# Name: hoursperweek, dtype: int64

# %%
df.hoursperweek.sort_values(ascending=True).head()
# Out:
# 19750    1
# 25078    1
# 11451    1
# 8447     1
# 32525    1
# Name: hoursperweek, dtype: int64

# %%
df.hoursperweek.describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hoursperweek, dtype: float64

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                count    %
# age                0  0.0
# workclass          0  0.0
# fnlwgt             0  0.0
# education          0  0.0
# educationnum       0  0.0
# maritalstatus      0  0.0
# occupation         0  0.0
# relationship       0  0.0
# race               0  0.0
# sex                0  0.0
# capitalgain        0  0.0
# capitalloss        0  0.0
# hoursperweek       0  0.0
# nativecountry      0  0.0
# income             0  0.0

# %%
df.workclass.value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df.education.value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df.educationnum.value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: educationnum, dtype: int64

# %%
df.maritalstatus.value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: maritalstatus, dtype: int64

# %%
df.occupation.value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df.relationship.value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64

# %%
df.race.value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
df.sex.value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
df.capitalgain.value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: capitalgain, Length: 119, dtype: int64

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income
# 0         2174            0            40   United-States   <=50K
# ...

# %%
df.capitalloss.value_counts()
# Out:
# 0       31042
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1411        1
# 1539        1
# 2472        1
# 1944        1
# 2201        1
# Name: capitalloss, Length: 92, dtype: int64

# %%
df.nativecountry.value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income
# 0         2174            0            40   United-States   <=50K
# ...

# %%
df.income.value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
df2 = df.set_index('age').groupby('age').mean()

# %%
df2.head()
# Out:
#             fnlwgt  educationnum  capitalgain  capitalloss  hoursperweek
# age
# 17   185722.232911      6.648101   109.691139    41.751899     21.367089
# 18   193530.207273      8.152727   102.058182    44.336364     25.912727
# 19   204803.543539      9.096910    92.092697    43.915730     30.678371
# 20   198537.705179      9.345286    82.786189    33.298805     32.280212
# 21   200116.997222      9.434722   204.625000    51.636111     34.034722

# %% [markdown]
# If income <=50k set income_bool to false, else true.

# %%
df['income_bool'] = df.income.apply(lambda x: True if x == ' >50K' else False)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income  income_bool
# ...

# %%
df[['income','income_bool']]
# Out:
#        income  income_bool
# 0       <=50K        False
# 1       <=50K        False
# 2       <=50K        False
# 3       <=50K        False
# 4       <=50K        False
# ...       ...          ...
# 32556   <=50K        False
# 32557    >50K         True
# 32558   <=50K        False
# 32559   <=50K        False
# 32560    >50K         True
#
# [32561 rows x 2 columns]

# %%
df['income_bool'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: income_bool, dtype: bool

# %%
df['income_bool'].value_counts()
# Out:
# False    24720
# True      7841
# Name: income_bool, dtype: int64

# %%
df.income.value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
df2 = df.set_index('age').groupby('age').mean()

# %%
df2.head()
# Out:
#             fnlwgt  educationnum  capitalgain  capitalloss  hoursperweek  \
# age
# 17   185722.232911      6.648101   109.691139    41.751899     21.367089
# 18   193530.207273      8.152727   102.058182    44.336364     25.912727
# 19   204803.543539      9.096910    92.092697    43.915730     30.678371
# 20   198537.705179      9.345286    82.786189    33.298805     32.280212
# 21   200116.997222      9.434722   204.625000    51.636111     34.034722
#
#      income_bool
# age
# 17      0.000000
# 18      0.000000
# 19      0.002809
# 20      0.000000
# 21      0.004167

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income  income_bool
# ...

# %%
df3 = df.set_index('nativecountry').groupby('nativecountry').mean()
df3.head()
# Out:
#                      age         fnlwgt  educationnum  capitalgain  \
# nativecountry
#  ?             38.725557  193300.897084     10.598628  1806.518010
#  Cambodia      37.789474  193080.368421      8.789474  1027.842105
#  Canada        42.545455  179852.933884     10.652893  1504.132231
#  China         42.533333  179047.986667     11.120000   366.480000
#  Columbia      39.711864  225149.406780      9.372881   180.610169
#
#                capitalloss  hoursperweek  income_bool
# nativecountry
#  ?              118.265866     41.512864     0.250429
#  Cambodia       183.052632     40.894737     0.368421
#  Canada         129.933884     40.404959     0.322314
#  China          179.520000     37.786667     0.266667
#  Columbia        27.152542     39.067797     0.033898

# %%
df4 = df.set_index('occupation').groupby('occupation').mean()
df4.head()
# Out:
#                         age         fnlwgt  educationnum  capitalgain  \
# occupation
#  ?                40.882800  188658.667390      9.253391   604.491047
#  Adm-clerical     36.964456  192043.396286     10.113528   495.954907
#  Armed-Forces     30.222222  215425.888889     10.111111     0.000000
#  Craft-repair     39.031471  192132.599658      9.110759   649.512808
#  Exec-managerial  42.169208  184414.012543     11.449090  2262.772996
#
#                   capitalloss  hoursperweek  income_bool
# occupation
#  ?                  60.529571     31.906131     0.103635
#  Adm-clerical       60.794430     37.558355     0.134483
#  Armed-Forces      209.666667     40.666667     0.111111
#  Craft-repair       88.465235     42.304221     0.226641
#  Exec-managerial   138.838416     44.987703     0.484014

# %%
df5 = df.set_index('sex').groupby('sex').mean()
df5.head()
# Out:
#                age         fnlwgt  educationnum  capitalgain  capitalloss  \
# sex
#  Female  36.858230  185746.311206     10.035744   568.410547    61.187633
#  Male    39.433547  191771.449013     10.102891  1329.370078   100.213309
#
#          hoursperweek  income_bool
# sex
#  Female     36.410361     0.109461
#  Male       42.428086     0.305737

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income  income_bool
# ...

# %%
df6 = df.set_index('race').groupby('race').mean()
df6.head()
# Out:
#                            age         fnlwgt  educationnum  capitalgain  \
# race
#  Amer-Indian-Eskimo  37.173633  120831.147910      9.311897   625.266881
#  Asian-Pac-Islander  37.746872  159940.609240     10.960539  1478.358037
#  Black               37.767926  228013.124200      9.486236   609.940461
#  Other               33.457565  197124.191882      8.841328   934.660517
#  White               38.769881  187298.064280     10.135246  1121.660375
#
#                      capitalloss  hoursperweek  income_bool
# race
#  Amer-Indian-Eskimo    34.176849     40.048232     0.115756
#  Asian-Pac-Islander    97.222329     40.127045     0.265640
#  Black                 60.385083     38.422855     0.123880
#  Other                 61.070111     39.468635     0.092251
#  White                 90.806155     40.689100     0.255860

# %%
df7 = df.set_index('education').groupby('education').mean()
df7
# Out:
#                      age         fnlwgt  educationnum   capitalgain  \
# education
#  10th          37.429796  196832.465166           6.0    404.574491
#  11th          32.355745  194928.077447           7.0    215.097872
#  12th          32.000000  199097.508083           8.0    284.087760
#  1st-4th       46.142857  239303.000000           2.0    125.875000
#  5th-6th       42.885886  232448.333333           3.0    176.021021
#  7th-8th       48.445820  188079.171827           4.0    233.939628
#  9th           41.060311  202485.066148           5.0    342.089494
#  Assoc-acdm    37.381443  193424.093721          12.0    640.399250
#  Assoc-voc     38.553546  181936.016643          11.0    715.051375
#  Bachelors     38.904949  188055.914846          13.0   1756.299533
#  Doctorate     47.702179  186698.760291          16.0   4770.145278
#  HS-grad       38.974479  189538.739739           9.0    576.800114
#  Masters       44.049913  179852.362739          14.0   2562.563552
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry  income  income_bool
# ...

# %%
df8 = df.set_index('age').groupby('age').mean()
df8.head(20)
# Out:
#             fnlwgt  educationnum  capitalgain  capitalloss  hoursperweek  \
# age
# 17   185722.232911      6.648101   109.691139    41.751899     21.367089
# 18   193530.207273      8.152727   102.058182    44.336364     25.912727
# 19   204803.543539      9.096910    92.092697    43.915730     30.678371
# 20   198537.705179      9.345286    82.786189    33.298805     32.280212
# 21   200116.997222      9.434722   204.625000    51.636111     34.034722
# 22   202336.500654      9.690196   352.631373    19.413072     35.171242
# 23   206116.502851     10.013683   103.099202    39.978335     36.718358
# 24   205230.456140     10.199248   280.729323    31.190476     39.088972
# 25   203066.870392     10.191439   279.297265    49.171225     40.007134
# 26   192976.476433     10.327389   341.630573    55.230573     41.064968
# 27   196381.977246     10.245509   255.560479    63.522156     42.039521
# 28   190923.176471     10.119954   551.802768    65.769319     42.027682
# ...

# %%
df.hist(figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     353     try:
# --> 354         dt = signed_to_unsigned[dt.type]
#     355     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-207-e8e0ff830b6f> in <module>
# ----> 1 df.hist(figsize=(15,10))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, **kwargs)
#     191     """
#     192     plot_backend = _get_plot_backend(backend)
# --> 193     return plot_backend.hist_frame(
#     194         data,
# ...
